# %% [markdown]
# <a href="https://colab.research.google.com/github/ybrefodlavir/PCVK_Genap/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kitten.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/kitten.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img2)

# %%
cv.rectangle(black_img2,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img2)

# %%
cv.rectangle(black_img2,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img2)

# %%
cv.circle(black_img2,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img2)

# %%
cv.line(black_img2,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img2)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img2,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img2)

# %%
black_img3=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img3)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img3,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img3)

# %%
#1. By using figsize, notice whether the image pixel size also changes?
imgfig = img3
plt.figure(figsize=(4,3))
plt.imshow(imgfig)

# %%
#2. Show images in Red-Green and Green-Blue channels only!
#Red Green
RG = cv.cvtColor(img,cv.COLOR_BGR2RGB)
RG[:,:,2] = 0
plt.imshow(RG)

# %%
#Green Blue
GB = cv.cvtColor(img,cv.COLOR_BGR2RGB)
GB[:,:,0] = 0
plt.imshow(GB)

# %%
#3. Show image row 10-100, column 10-100!
cat = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cat = cat[10:100,10:100]
plt.imshow(cat)

# %%
#4. Show image rows 5-30, all columns, channel Green only!
GreenCat = cv.cvtColor(img,cv.COLOR_BGR2RGB)
GreenCat = GreenCat[5:30]
GreenCat[:,:,0]=0
GreenCat[:,:,2]=0
plt.imshow(GreenCat)

# %%
#5. Create 5 boxes of different sizes and colors in one image. it is recommended to use random numbers!
pict = cv.imread('/content/drive/MyDrive/pic.jpg')
pict = cv.cvtColor(pict,cv.COLOR_BGR2RGB)
cv.rectangle (pict, pt1=(100,100), pt2=(150,170), color=(255,255,255),thickness=10)
cv.rectangle (pict, pt1=(200,200), pt2=(250,270), color=(255,255,0),thickness=10)
cv.rectangle (pict, pt1=(300,300), pt2=(350,370), color=(255,0,0),thickness=10)
cv.rectangle (pict, pt1=(400,200), pt2=(450,270), color=(0,0,255),thickness=10)
cv.rectangle (pict, pt1=(500,200), pt2=(550,100), color=(0,255,255),thickness=10)
plt.imshow(pict)

# %%
#6. Show the image upside down!
pict2 = cv.flip(pict,0)
plt.imshow(pict2)

# %%
#7. Make rectangles and circles on the face of your photo image when you are active
kitten = img2
kitten = cv.cvtColor(kitten,cv.COLOR_BGR2RGB)
cv.rectangle(kitten,pt1=(100,40),pt2=(175,125), color=(0,0,255),thickness=5)
cv.circle(kitten,center=(135,80),radius=35,color=(255,0,0),thickness=5)
plt.imshow(kitten)

# %%
#8. Create a rectangle in the lower left corner of channel B in the RGB color space from 
#the kitten / lena / mandrill / male / female / couple / sailboat / peppers image !
kitten1 = img2
kitten1 = cv.cvtColor(kitten1,cv.COLOR_BGR2RGB)
cv.rectangle(kitten1,pt1=(0,120),pt2=(50,165), color=(0,255,0),thickness=5)
plt.imshow(kitten1)

# %%
#9. Complete the writing of the file name on the image file from question no.8. use the 
#font, font size, and font color according to your wishes.
blackimage=np.zeros(shape=(512,512,3),dtype=np.int32)
font = cv.FONT_ITALIC
cv.putText(blackimage,text='Rivaldo Ferby',org=(50,270),fontFace=font,fontScale=2,color=(255,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(blackimage)
